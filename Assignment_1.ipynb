# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Task 1

# %%
  np.random.seed(30)
  data=np.random.rand(4,4)
  data
# Out:
# array([[0.64414354, 0.38074849, 0.66304791, 0.16365073],
#        [0.96260781, 0.34666184, 0.99175099, 0.2350579 ],
#        [0.58569427, 0.4066901 , 0.13623432, 0.54413629],
#        [0.51817635, 0.76685511, 0.93385014, 0.08970338]])

# %%
columns=['Feature1','Feature2','Feature3','Feature4']
df=pd.DataFrame(data,columns=columns)
df
# Out:
#    Feature1  Feature2  Feature3  Feature4
# 0  0.644144  0.380748  0.663048  0.163651
# 1  0.962608  0.346662  0.991751  0.235058
# 2  0.585694  0.406690  0.136234  0.544136
# 3  0.518176  0.766855  0.933850  0.089703

# %% [markdown]
# Task 2

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.644144        0.380748        0.663048        0.163651
# 1        0.962608        0.346662        0.991751        0.235058
# 2        0.585694        0.406690        0.136234        0.544136
# 3        0.518176        0.766855        0.933850        0.089703

# %% [markdown]
# Task 3

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.677655        0.475239        0.681221        0.258137
# std          0.196817        0.195959        0.390551        0.199688
# min          0.518176        0.346662        0.136234        0.089703
# 25%          0.568815        0.372227        0.531345        0.145164
# 50%          0.614919        0.393719        0.798449        0.199354
# 75%          0.723760        0.496731        0.948325        0.312327
# max          0.962608        0.766855        0.991751        0.544136

# %% [markdown]
# Task 4

# %%
df.isnull().any()
# Out:
# Random value 1    False
# Random value 2    False
# Random value 3    False
# Random value 4    False
# dtype: bool

# %%
  df.dtypes
# Out:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %% [markdown]
# Task 5

# %%
df.loc[:,'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.380748        0.663048
# 1        0.346662        0.991751
# 2        0.406690        0.136234
# 3        0.766855        0.933850

# %%
df.iloc[:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.380748        0.663048
# 1        0.346662        0.991751
# 2        0.406690        0.136234
# 3        0.766855        0.933850
